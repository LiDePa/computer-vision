# %% [markdown]
# ## Hello world!
#
# This is a Jupyter notebook. It can contain both text and code, arranged into cells.
# This allows for easy partial execution of code blocks to debug and test your code.
#
# Running a cell executes all code lines in it and displays any output below.
# The interpreter state is maintained between the execution of cells, so you don't always need to rerun all cells.
# However, when modifying variables, take care that the proper execution order is maintained.
#
# Now, try to run the next cell. If everything is set up correctly, it should show a simple line plot.

# %%
print("hello world!")

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 4*np.pi, 100)
plt.plot(x, np.sin(x))
plt.show()

import torch
print('torch.cuda:', torch.cuda.is_available())
t = torch.tensor(x)
# Out:
# hello world!
# torch.cuda: True
